# %%
import sys
sys.path.insert(0, '../')

import train_segnet
import importlib
importlib.reload(train_segnet)

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

# %%
train = train_segnet.EstimatedCityscapesDataset(
    '../data/cityscapes/leftImg8bit/train',
    '../data/estimated_train_labels',
    [256, 512]
)

valid = train_segnet.CityscapesRoadDataset('../data/cityscapes/', [256, 512])

# %%
print(len(train))
for i in range(3):
    print(i)
    img, label = train[i]
    
    print(np.unique(label), img.shape, label.shape)
    
    img -= img.min(axis=(1, 2))[:, None, None]
    img /= img.max(axis=(1, 2))[:, None, None]
    plt.imshow(img.transpose(1, 2, 0))
    plt.imshow(label, alpha=0.6, cmap=plt.cm.Set1_r)
    plt.show()
# Out:
# 2975
# 0
# [0 1] (3, 256, 512) (256, 512)
# 1
# [0 1] (3, 256, 512) (256, 512)
# 2
# [0 1] (3, 256, 512) (256, 512)

# %%
print(len(valid))
for i in range(10):
    print(i)
    img, label = valid[i]
    
    print(np.unique(label), img.shape, label.shape)
    img -= img.min(axis=(1, 2))[:, None, None]
    img /= img.max(axis=(1, 2))[:, None, None]
    plt.imshow(img.transpose(1, 2, 0))
    plt.imshow(label, alpha=0.6, cmap=plt.cm.Set1_r)
    plt.show()
    plt.imshow(label)
    plt.show()
# Out:
# 500
# 0
# [-1  0  1] (3, 256, 512) (256, 512)
# 1
# [-1  0  1] (3, 256, 512) (256, 512)
# 2
# [-1  0  1] (3, 256, 512) (256, 512)
# 3
# [-1  0  1] (3, 256, 512) (256, 512)
# 4
# [-1  0  1] (3, 256, 512) (256, 512)
# 5
# [-1  0  1] (3, 256, 512) (256, 512)
# 6
# [-1  0  1] (3, 256, 512) (256, 512)
# 7
# [-1  0  1] (3, 256, 512) (256, 512)
# 8
# [-1  0  1] (3, 256, 512) (256, 512)
# 9
# [-1  0  1] (3, 256, 512) (256, 512)
